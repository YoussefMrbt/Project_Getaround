# %% [markdown]
# ![snap](https://lever-client-logos.s3.amazonaws.com/2bd4cdf9-37f2-497f-9096-c2793296a75f-1568844229943.png)
#
# # GetAround
#
# [GetAround](https://www.getaround.com/?wpsrc=Google+Organic+Search) is the Airbnb for cars. You can rent cars from any person for a few hours to a few days! Founded in 2009, this company has known rapid growth. In 2019, they count over 5 million users and about 20K available cars worldwide.
#
# As Jedha's partner, they offered this great challenges:
#
# ## Context
#
# When renting a car, our users have to complete a checkin flow at the beginning of the rental and a checkout flow at the end of the rental in order to:
#
# * Assess the state of the car and notify other parties of pre-existing damages or damages that occurred during the rental.
# * Compare fuel levels.
# * Measure how many kilometers were driven.
#
# The checkin and checkout of our rentals can be done with three distinct flows:
# * **📱 Mobile** rental agreement on native apps: driver and owner meet and both sign the rental agreement on the owner’s smartphone
# * **Connect:** the driver doesn’t meet the owner and opens the car with his smartphone
# * **📝 Paper** contract (negligible)
#
# ## Project 🚧
#
# For this case study, we suggest that you put yourselves in our shoes, and run an analysis we made back in 2017 🔮 🪄
#
# When using Getaround, drivers book cars for a specific time period, from an hour to a few days long. They are supposed to bring back the car on time, but it happens from time to time that drivers are late for the checkout.
#
# Late returns at checkout can generate high friction for the next driver if the car was supposed to be rented again on the same day : Customer service often reports users unsatisfied because they had to wait for the car to come back from the previous rental or users that even had to cancel their rental because the car wasn’t returned on time.
#
#
# ## Goals 🎯
#
# In order to mitigate those issues we’ve decided to implement a minimum delay between two rentals. A car won’t be displayed in the search results if the requested checkin or checkout times are too close from an already booked rental.
#
# It solves the late checkout issue but also potentially hurts Getaround/owners revenues: we need to find the right trade off.
#
# **Our Product Manager still needs to decide:**
# * **threshold:** how long should the minimum delay be?
# * **scope:** should we enable the feature for all cars?, only Connect cars?
#
# In order to help them make the right decision, they are asking you for some data insights. Here are the first analyses they could think of, to kickstart the discussion. Don’t hesitate to perform additional analysis that you find relevant.
#
# * Which share of our owner’s revenue would potentially be affected by the feature?
# * How many rentals would be affected by the feature depending on the threshold and scope we choose?
# * How often are drivers late for the next check-in? How does it impact the next driver?
# * How many problematic cases will it solve depending on the chosen threshold and scope?
#
# ### Web dashboard
#
# First build a dashboard that will help the product Management team with the above questions. You can use `streamlit` or any other technology that you see fit.
#
#
# ### Machine Learning - `/predict` endpoint
#
# In addition to the above question, the Data Science team is working on *pricing optimization*. They have gathered some data to suggest optimum prices for car owners using Machine Learning.
#
# You should provide at least **one endpoint** `/predict`. The full URL would look like something like this: `https://your-url.com/predict`.
#
# This endpoint accepts **POST method** with JSON input data and it should return the predictions. We assume **inputs will be always well formatted**. It means you do not have to manage errors. We leave the error handling as a bonus.
#
# Input example:
#
# ```
# {
#   "input": [[7.0, 0.27, 0.36, 20.7, 0.045, 45.0, 170.0, 1.001, 3.0, 0.45, 8.8], [7.0, 0.27, 0.36, 20.7, 0.045, 45.0, 170.0, 1.001, 3.0, 0.45, 8.8]]
# }
# ```
#
# The response should be a JSON with one key `prediction` corresponding to the prediction.
#
# Response example:
#
# ```
# {
#   "prediction":[6,6]
# }
# ```
#
# ### Documentation page
#
# You need to provide the users with a **documentation** about your API.
#
# It has to be located at the `/docs` of your website. If we take the URL example above, it should be located directly at `https://your-url.com/docs`).
#
# This small documentation should at least include:
# - An h1 title: the title is up to you.
# - A description of every endpoints the user can call with the endpoint name, the HTTP method, the required input and the expected output (you can give example).
#
# You are free to add other any other relevant informations and style your HTML as you wish.
#
# ### Online production
#
# You have to **host your API online**. We recommend you to use [Heroku](https://www.heroku.com/) as it is free of charge. But you are free to choose any other hosting provider.
#
# ## Helpers 🦮
#
# To help you start with this project we provide you with some pieces of advice:
#
# * Spend some time understanding data
# * Don't overlook Data Analysis part, there is a lot of insights to find out.
# * Data Analysis should take 2 to 5 hours
# * Machine Learning should take 3 to 6 hours
# * You are not obligated to use libraries to handle your Machine Learning workflow like `mlflow` but we definitely advise you to do so.
#
#
# ### Share your code
#
# In order to get evaluation, do not forget to share your code on a [Github](https://github.com/) repository. You can create a [`README.md`](https://guides.github.com/features/mastering-markdown/) file with a quick description about this project, how to setup locally and the online URL.
#
# ## Deliverable 📬
#
# To complete this project, you should deliver:
#
# - A **dashboard** in production (accessible via a web page for example)
# - The **whole code** stored in a **Github repository**. You will include the repository's URL.
# - An **documented online API** on Heroku server (or any other provider you choose) containing at least **one `/predict` endpoint** that respects the technical description above. We should be able to request the API endpoint `/predict` using `curl`:
#
# ```shell
# $ curl -i -H "Content-Type: application/json" -X POST -d '{"input": [[7.0, 0.27, 0.36, 20.7, 0.045, 45.0, 170.0, 1.001, 3.0, 0.45, 8.8]]}' http://your-url/predict
# ```
#
# Or Python:
#
# ```python
# import requests
#
# response = requests.post("https://your-url/predict", json={
#     "input": [[7.0, 0.27, 0.36, 20.7, 0.045, 45.0, 170.0, 1.001, 3.0, 0.45, 8.8]]
# })
# print(response.json())
# ```
#
# ## Data
#
# There are two files you need to download:
#
# * [Delay Analysis](https://full-stack-assets.s3.eu-west-3.amazonaws.com/Deployment/get_around_delay_analysis.xlsx) 👈 Data Analysis
# * [Pricing Optimization](https://full-stack-assets.s3.eu-west-3.amazonaws.com/Deployment/get_around_pricing_project.csv) 👈 Machine Learning
#
#
# Happy coding! 👩‍💻

# %% [markdown]
# #   Plan
#
# 1. Introduction
# 2.  Importing Libraries
# 3.  Importing Data
# 4. Machine Learning
# 5. Github
# 6. API
# 7. Conclusion

# %% [markdown]
# #   Introduction
#
# Late returns are a significant operational challenge for Getaround, leading to dissatisfaction among users when cars are not returned on time for the next rental. To address this, Getaround is considering implementing a minimum delay between rentals, necessitating a careful balance between improving user experience and preserving or enhancing car owners' revenue. This strategic decision requires a deep dive into data-driven insights to determine the optimal threshold for rental delays and the scope of cars this feature should apply to, whether all or only Connect cars.
#
# Objectives
# This notebook focuses on developing a machine learning model to predict the daily rental price of cars listed on Getaround. The prediction model aims to support strategic decisions by:
#
# Predicting the rental price per day based on various factors such as car type, mileage, options and time between rentals, aiding in understanding how these variables influence pricing strategies.

# %% [markdown]
# #   Importing libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import  OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import Lasso, Ridge
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingRegressor
import pickle

from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import cross_val_score

# %% [markdown]
# #   Importing Data

# %%
#Importing csv file
pathfile2 = 'Data/get_around_pricing_project.csv' 
data = pd.read_csv(pathfile2)
drop_col = 'Unnamed: 0'
data = data.drop(columns= drop_col)

# %%
data.head()
# Out:
#   model_key  mileage  engine_power    fuel paint_color     car_type  \
# 0   Citroën   140411           100  diesel       black  convertible
# 1   Citroën    13929           317  petrol        grey  convertible
# 2   Citroën   183297           120  diesel       white  convertible
# 3   Citroën   128035           135  diesel         red  convertible
# 4   Citroën    97097           160  diesel      silver  convertible
#
#    private_parking_available  has_gps  has_air_conditioning  automatic_car  \
# 0                       True     True                 False          False
# 1                       True     True                 False          False
# 2                      False    False                 False          False
# 3                       True     True                 False          False
# 4                       True     True                 False          False
#
#    has_getaround_connect  has_speed_regulator  winter_tires  \
# ...

# %%
"""Depiction of dataset variables and statistics"""
#Dataset information
print('Dataset information')
print(data.info())
#Top 5 rows of dataset
display('Dataset:', data.head())
print('General statistics of the dataset:')
display(data.describe(include='all'))
print('Number of rows:', data.shape[0])
print('Number of columns:', data.shape[1])
print()
print('Missing values for each variable')
display(data.isnull().sum())
print('percentage of missing value')
display(data.isna().sum() / (data.isna().sum() + data.count()) * 100)
# Out:
# Dataset information
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4843 entries, 0 to 4842
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   model_key                  4843 non-null   object
#  1   mileage                    4843 non-null   int64
#  2   engine_power               4843 non-null   int64
#  3   fuel                       4843 non-null   object
#  4   paint_color                4843 non-null   object
#  5   car_type                   4843 non-null   object
#  6   private_parking_available  4843 non-null   bool
#  7   has_gps                    4843 non-null   bool
#  8   has_air_conditioning       4843 non-null   bool
#  9   automatic_car              4843 non-null   bool
#  10  has_getaround_connect      4843 non-null   bool
#  11  has_speed_regulator        4843 non-null   bool
#  12  winter_tires               4843 non-null   bool
# ...

# %%
'''
The dataset has no missing values, and contains 4843 rows and 14 columns, which are composed of 2 numerical variables and 12 categorical variables. 
An outlier is observed in the variable 'mileage' with negative values, which is not possible and one extreme value over 1 000 000.
'''
# Out:
# "\nThe dataset has no missing values, and contains 4843 rows and 14 columns, which are composed of 2 numerical variables and 12 categorical variables. \nAn outlier is observed in the variable 'mileage' with negative values, which is not possible and one extreme value over 1 000 000.\n"

# %%
# Replace rare model_key by 'other'
print("Replacing rare model_key by 'other'...")
model_counts = data.model_key.value_counts()
rare_model = model_counts[model_counts < 15].index

# Mapping rare model to 'other'
data.model_key = data.model_key.replace(rare_model, 'Other')
print("...Done.")

# Drop rows where mileage is negative
print("Dropping rows where mileage is negative...and an extreme outlier")
data = data[(data.mileage > 0) & (data.mileage < 1e6)]
print("...Done.")

# Copy data into data_cleaned
print("Copying data into data_cleaned...")
data_cleaned = data.copy()
# Out:
# Replacing rare model_key by 'other'...
# ...Done.
# Dropping rows where mileage is negative...and an extreme outlier
# ...Done.
# Copying data into data_cleaned...

# %% [markdown]
# # Exploration Data Analysis

# %%
# Plot histogram of model_key, horizontal
print("Plotting histogram of model_key, horizontal...")
data_cleaned.model_key.value_counts().plot(kind='barh', figsize=(10, 10), title='Model key histogram', color='skyblue', edgecolor='black', fontsize=12)
plt.xlabel('Count')
print("...Done.")
# Out:
# Plotting histogram of model_key, horizontal...
# ...Done.

# %% [markdown]
# The number of rental by car model.

# %%
# PLot mileage distribution
print("Plotting mileage distribution...")
data_cleaned.mileage.plot(kind='hist', bins=100, figsize=(10, 10), title='Mileage distribution', color='skyblue', edgecolor='black')
plt.xlabel('Mileage')
print("...Done.")
# Out:
# Plotting mileage distribution...
# ...Done.

# %% [markdown]
# Distribution of mileage

# %%
# Plot model_key vs rental_price_per_day in ascending order
print("Plotting model_key vs rental_price_per_day in ascending order...")
data_cleaned.groupby('model_key').rental_price_per_day.mean().sort_values().plot(kind='barh', figsize=(10, 10), title='Model key vs rental_price_per_day', color='skyblue', edgecolor='black', fontsize=12)
plt.xlabel('Rental price per day')
print("...Done.")
# Out:
# Plotting model_key vs rental_price_per_day in ascending order...
# ...Done.

# %% [markdown]
# Average rental price per day by car model present in the pool of cars rented with Getaround.

# %%
# Plot rental_price_per_day vs engine_power
print("Plotting rental_price_per_day vs engine_power...")
data_cleaned.plot(kind='scatter', x='engine_power', y='rental_price_per_day', figsize=(10, 10), title='Rental_price_per_day vs engine_power', color='skyblue')
print("...Done.")
# Out:
# Plotting rental_price_per_day vs engine_power...
# ...Done.

# %% [markdown]
# We can observe a trend between the engine power and the rental price per day, with an increase of the price when the engine power increases in an almost linear way.

# %% [markdown]
# #   Preprocessing

# %%
# Separate target variable Y from features X
print("Separating target variable Y from features X...")
target_variable = "rental_price_per_day"
features = data_cleaned.drop(columns=target_variable).columns.tolist()

X = data_cleaned.loc[:,features]
Y = data_cleaned.loc[:,target_variable]

print("...Done.")
print()

print('Y : ')
print(Y.head())
print()

print('X :')
print(X.head())
# Out:
# Separating target variable Y from features X...
# ...Done.
#
# Y :
# 0    106
# 1    264
# 2    101
# 3    158
# 4    183
# Name: rental_price_per_day, dtype: int64
#
# X :
#   model_key  mileage  engine_power    fuel paint_color     car_type  \
# 0   Citroën   140411           100  diesel       black  convertible
# 1   Citroën    13929           317  petrol        grey  convertible
# 2   Citroën   183297           120  diesel       white  convertible
# 3   Citroën   128035           135  diesel         red  convertible
# 4   Citroën    97097           160  diesel      silver  convertible
#
#    private_parking_available  has_gps  has_air_conditioning  automatic_car  \
# 0                       True     True                 False          False
# 1                       True     True                 False          False
# 2                      False    False                 False          False
# 3                       True     True                 False          False
# ...

# %%
# Divide dataset Train set & Test set 
print("Dividing into train and test sets...")
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0, stratify=X['model_key'])
print("...Done.")
print()
X_train.head()
# Out:
# Dividing into train and test sets...
# ...Done.
#      model_key  mileage  engine_power    fuel paint_color     car_type  \
# 3219   Renault   138693           140  diesel        grey        sedan
# 1573   Citroën   400654           110  diesel       black       estate
# 37     Peugeot    24452           270  petrol        grey  convertible
# 404       Audi   119760           190  diesel       black       estate
# 951    Peugeot   160571           100  diesel       black       estate
#
#       private_parking_available  has_gps  has_air_conditioning  automatic_car  \
# 3219                      False     True                 False          False
# 1573                      False    False                  True          False
# 37                         True    False                 False          False
# 404                        True     True                  True           True
# 951                       False     True                 False          False
#
# ...

# %%
# Automatically detect names of numeric/categorical columns
numeric_features = []
categorical_features = []
for i,t in X.dtypes.items():
    if ('float' in str(t)) or ('int' in str(t)) :
        numeric_features.append(i)
    else :
        categorical_features.append(i)

print('Found numeric features ', numeric_features)
print('Found categorical features ', categorical_features)
# Out:
# Found numeric features  ['mileage', 'engine_power']
# Found categorical features  ['model_key', 'fuel', 'paint_color', 'car_type', 'private_parking_available', 'has_gps', 'has_air_conditioning', 'automatic_car', 'has_getaround_connect', 'has_speed_regulator', 'winter_tires']

# %%
# Create pipeline for numeric features
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')), # missing values will be replaced by columns' median
    ('scaler', StandardScaler())
])

# Create pipeline for categorical features
categorical_transformer = Pipeline(
    steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OneHotEncoder(drop='first')) # first column will be dropped to avoid creating correlations between features
    ])

# Create preprocessor
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ])

# %%
# Fit preprocessor to training data
X_train = preprocessor.fit_transform(X_train)
print("...Done!")
print(X_train[0:5,:]) # X_train is now a numpy array
print()
# Out:
# ...Done!
#   (0, 0)	-0.0458648069344786
#   (0, 1)	0.273985429940141
#   (0, 13)	1.0
#   (0, 25)	1.0
#   (0, 33)	1.0
#   (0, 38)	1.0
#   (0, 41)	1.0
#   (0, 43)	1.0
#   (1, 0)	4.336830270592301
#   (1, 1)	-0.4851536679953321
#   (1, 3)	1.0
#   (1, 21)	1.0
#   (1, 31)	1.0
#   (1, 39)	1.0
#   (1, 43)	1.0
#   (2, 0)	-1.9571549163467075
#   (2, 1)	3.5635881876605247
#   (2, 12)	1.0
#   (2, 20)	1.0
#   (2, 25)	1.0
#   (2, 37)	1.0
#   (2, 43)	1.0
#   (3, 0)	-0.3626202243546844
#   (3, 1)	1.5392172598325964
#   (3, 21)	1.0
#   (3, 31)	1.0
#   (3, 37)	1.0
#   (3, 38)	1.0
#   (3, 39)	1.0
#   (3, 40)	1.0
#   (3, 41)	1.0
#   (3, 43)	1.0
#   (4, 0)	0.32016144470653246
#   (4, 1)	-0.7382000339738232
#   (4, 12)	1.0
#   (4, 21)	1.0
#   (4, 31)	1.0
#   (4, 38)	1.0
#   (4, 43)	1.0

# %%
# Preprocess X_test data
print("Preprocessing X_test...")
print(X_test.head())
print()
X_test = preprocessor.transform(X_test)
print("...Done!")
print(X_test[0:5,:]) # X_test is now a numpy array
print()
# Out:
# Preprocessing X_test...
#      model_key  mileage  engine_power    fuel paint_color   car_type  \
# 3060   Renault   202696           130  diesel       black      sedan
# 3523      Audi   187367           180  diesel       black      sedan
# 1629   Renault   156165           120  diesel       black     estate
# 1906       BMW   219512            85  diesel        blue  hatchback
# 1096      Audi   186203           190  diesel       black     estate
#
#       private_parking_available  has_gps  has_air_conditioning  automatic_car  \
# 3060                      False     True                 False          False
# 3523                       True     True                 False          False
# 1629                       True     True                  True          False
# 1906                       True     True                 False          False
# 1096                       True     True                 False          False
#
# ...

# %% [markdown]
# #   Models processing

# %%
# Initialize table to store the results
results = pd.DataFrame(columns = ['Model', 'R2_train', 'R2_test' , 'RMSE'])

# %% [markdown]
# ##   Model Linear Regression

# %%
# Train model with Linear Regression
print("Training model with Linear Regression...")
model = LinearRegression()
model.fit(X_train, Y_train)
print("...Done.")

# Predictions
print("Predictions...")
Y_train_pred = model.predict(X_train)
Y_test_pred = model.predict(X_test)
print("...Done.")

# R2 score
print("R2 score...")
r2_train = r2_score(Y_train, Y_train_pred)
print("R2 train : ", r2_train)
r2_test = r2_score(Y_test, Y_test_pred)
print("R2 test : ", r2_test)
print("...Done.")

# Metrics for model evaluation
print("MSE : ", mean_squared_error(Y_test, Y_test_pred))
print("RMSE : ", np.sqrt(mean_squared_error(Y_test, Y_test_pred)))
print("Variance : ", np.var(Y_test))
print("RMSE / Variance : ", np.sqrt(mean_squared_error(Y_test, Y_test_pred)) / np.var(Y_test))
print("RMSE / (max(Y) - min(Y)) : ", np.sqrt(mean_squared_error(Y_test, Y_test_pred)) / (np.max(Y_test) - np.min(Y_test)))

# Add results to table
print("Adding results to table...")
results = results._append({'Model':'Linear Regression', 'R2_train':r2_train, 'R2_test':r2_test, 'RMSE':np.sqrt(mean_squared_error(Y_test, Y_test_pred))}, ignore_index=True)
print("...Done.")

# Save model pickle
filename = 'model_linear.pkl'
pickle.dump(model, open(filename, 'wb'))
# Out:
# Training model with Linear Regression...
# ...Done.
# Predictions...
# ...Done.
# R2 score...
# R2 train :  0.7210553087313772
# R2 test :  0.6599383742957192
# ...Done.
# MSE :  345.39303851204716
# RMSE :  18.584752850442946
# Variance :  1015.6777842743192
# RMSE / Variance :  0.018297882594450334
# RMSE / (max(Y) - min(Y)) :  0.050502045789247135
# Adding results to table...
# ...Done.

# %%
# Plot predictions vs true values
plt.scatter(Y_test, Y_test_pred)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.axis('equal')
plt.axis('square')
plt.plot(Y_test, Y_test, color='red')
plt.show()

# %%
# Residuals distribution
residuals = Y_test - Y_test_pred
sns.histplot(residuals, kde=True)
plt.title('Residuals distribution')
plt.show()

# %% [markdown]
# ##   Model Lasso

# %%
# Train model with different alpha
alphas = [0.1, 0.5, 1, 5, 10, 50, 100, 500, 1000]
scores = []
for alpha in alphas:
    print("Training model with alpha=", alpha, "...")
    model = Lasso(alpha=alpha)
    model.fit(X_train, Y_train)
    Y_train_pred = model.predict(X_train)
    score = r2_score(Y_train, Y_train_pred)
    scores.append(score)
    print("...Done.")
    print()

# Plot alpha vs R2 score
plt.plot(alphas, scores, 'o-')
plt.xscale('log')
plt.xlabel('alpha')
plt.ylabel('R2 score')
plt.title('alpha vs R2 score')
plt.show()
# Out:
# Training model with alpha= 0.1 ...
# ...Done.
#
# Training model with alpha= 0.5 ...
# ...Done.
#
# Training model with alpha= 1 ...
# ...Done.
#
# Training model with alpha= 5 ...
# ...Done.
#
# Training model with alpha= 10 ...
# ...Done.
#
# Training model with alpha= 50 ...
# ...Done.
#
# Training model with alpha= 100 ...
# ...Done.
#
# Training model with alpha= 500 ...
# ...Done.
#
# Training model with alpha= 1000 ...
# ...Done.

# %%
# Train model with best alpha
best_alpha = alphas[scores.index(max(scores))]
print("Training model with best alpha=", best_alpha, "...")
model = Lasso(alpha=best_alpha)
model.fit(X_train, Y_train)
print("...Done.")
print()

# Predictions on training set
print("Predictions on training set...")
Y_train_pred = model.predict(X_train)
print("...Done.")
print(Y_train_pred)
print()

# Predictions on test set
print("Predictions on test set...")
Y_test_pred = model.predict(X_test)
print("...Done.")

# Print R^2 scores
print("R2 score on training set : ", r2_score(Y_train, Y_train_pred))
print("R2 score on test set : ", r2_score(Y_test, Y_test_pred))

# Metrics for model evaluation
print("MSE : ", mean_squared_error(Y_test, Y_test_pred))
print("RMSE : ", np.sqrt(mean_squared_error(Y_test, Y_test_pred)))
print("Variance : ", np.var(Y_test))
print("RMSE / Variance : ", np.sqrt(mean_squared_error(Y_test, Y_test_pred)) / np.var(Y_test))
print("RMSE / (max(Y) - min(Y)) : ", np.sqrt(mean_squared_error(Y_test, Y_test_pred)) / (np.max(Y_test) - np.min(Y_test)))

# Store results
results = results._append({'Model': 'Lasso', 'R2_train': r2_score(Y_train, Y_train_pred), 'R2_test': r2_score(Y_test, Y_test_pred), 'RMSE': np.sqrt(mean_squared_error(Y_test, Y_test_pred))}, ignore_index=True)
# Out:
# Training model with best alpha= 0.1 ...
# ...Done.
#
# Predictions on training set...
# ...Done.
# [134.93613715  30.25353633 172.67630236 ... 115.04928896 105.945923
#  132.09315144]
#
# Predictions on test set...
# ...Done.
# R2 score on training set :  0.7049770063649614
# R2 score on test set :  0.6533623444193433
# MSE :  352.0721659662064
# RMSE :  18.763586170191626
# Variance :  1015.6777842743192
# RMSE / Variance :  0.01847395548145992
# RMSE / (max(Y) - min(Y)) :  0.05098800589725985

# %% [markdown]
# The provided metrics indicate that the model has a certain level of accuracy in predicting the target variable, with errors that are relatively small compared to the variability and the range of the data. The RMSE of 19.35 units, compared to the variance and range of the target variable, suggests the model captures the data's underlying pattern to a reasonable extent but still has room for improvement.

# %%
# Matrix of coefficients
print("Coefficients : ", model.coef_)
print("Intercept : ", model.intercept_)
print()
# Out:
# Coefficients :  [-13.93468243  15.24028162  -8.24449131  -5.98894446   0.
#    0.           3.25167261   0.         -16.28421593   0.
#   -0.          -7.41156719  -1.57521308   4.24837826   1.30794929
#    0.           0.           0.90148381   0.           0.
#  -17.08742932   1.12887053  -0.81986689   1.54020454  -0.
#   -0.          -0.           0.          -3.3104792    3.94356011
#    0.90270911  -6.45681067  -0.           0.          -0.
#   13.09856863  -0.           1.34320063  12.10023988   0.98332767
#    3.64509852   5.35946802   4.52103831  -1.00403091]
# Intercept :  109.41735526268897

# %%
# Cross validation
scores = cross_val_score(model, X_train, Y_train, cv=5)
print("Cross validation scores : ", scores)
print("Mean cross validation score : ", scores.mean())
print("Standard deviation of cross validation scores : ", scores.std())
# Out:
# Cross validation scores :  [0.69165614 0.67237534 0.67330698 0.73294068 0.73056474]
# Mean cross validation score :  0.7001687760104428
# Standard deviation of cross validation scores :  0.02669984669285044

# %%
# Plot predictions vs true values
plt.scatter(Y_test, Y_test_pred)
plt.xlabel('True values')
plt.ylabel('Predictions')
plt.title('Predictions vs true values')
plt.axis('equal')
plt.axis('square')
plt.plot(Y_test, Y_test, color='red')
plt.show()

# %%
# Plot residuals distribution
sns.distplot(Y_test_pred - Y_test)
plt.title('Residuals distribution')
plt.show()
# Out:
# C:\Users\morab\AppData\Local\Temp\ipykernel_10600\308173877.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Y_test_pred - Y_test)

# %%
# Plot feature importance, including OneHotEncoder column names
print("Plotting feature importance...")
onehot_columns = list(preprocessor.named_transformers_['cat'].named_steps['encoder'].get_feature_names_out(input_features=categorical_features))
numeric_features_list = numeric_features
numeric_features_list.extend(onehot_columns)
feature_importance = pd.DataFrame({'feature': numeric_features_list, 'importance': model.coef_})
feature_importance.set_index('feature', inplace=True)
feature_importance.importance = feature_importance.importance.abs()
feature_importance.sort_values(by='importance', ascending=True).plot(kind='barh', figsize=(10, 10), title='Feature importance', color='skyblue', edgecolor='black', fontsize=12)
print("...Done.")
# Out:
# Plotting feature importance...
# ...Done.

# %%
# Save model
import pickle
pickle.dump(model, open('model_lasso.pkl','wb'))

# %% [markdown]
# #   Model Ridge

# %%
# Train Ridge model with different alpha
alphas = [0.1, 0.5, 1, 5, 10, 50, 100, 500, 1000]
scores = []
for alpha in alphas:
    print("Training model with alpha=", alpha, "...")
    model = Ridge(alpha=alpha)
    model.fit(X_train, Y_train)
    Y_train_pred = model.predict(X_train)
    score = r2_score(Y_train, Y_train_pred)
    scores.append(score)
    print("...Done.")
    print()

# Plot alpha vs R2 score
plt.plot(alphas, scores, 'o-')
plt.xscale('log')
plt.xlabel('alpha')
plt.ylabel('R2 score')
plt.title('alpha vs R2 score')
plt.show()
# Out:
# Training model with alpha= 0.1 ...
# ...Done.
#
# Training model with alpha= 0.5 ...
# ...Done.
#
# Training model with alpha= 1 ...
# ...Done.
#
# Training model with alpha= 5 ...
# ...Done.
#
# Training model with alpha= 10 ...
# ...Done.
#
# Training model with alpha= 50 ...
# ...Done.
#
# Training model with alpha= 100 ...
# ...Done.
#
# Training model with alpha= 500 ...
# ...Done.
#
# Training model with alpha= 1000 ...
# ...Done.

# %%
# Train Ridge model with best alpha
best_alpha = alphas[scores.index(max(scores))]
print("Training model with best alpha=", best_alpha, "...")
model = Ridge(alpha=best_alpha)
model.fit(X_train, Y_train)
print("...Done.")
print()

# Predictions on training set
print("Predictions on training set...")
Y_train_pred = model.predict(X_train)
print("...Done.")
print(Y_train_pred)
print()

# Predictions on test set
print("Predictions on test set...")
Y_test_pred = model.predict(X_test)
print("...Done.")

# Print R^2 scores
print("R2 score on training set : ", r2_score(Y_train, Y_train_pred))
print("R2 score on test set : ", r2_score(Y_test, Y_test_pred))

# Metrics for model evaluation
print("MSE : ", mean_squared_error(Y_test, Y_test_pred))
print("RMSE : ", np.sqrt(mean_squared_error(Y_test, Y_test_pred)))
print("Variance : ", np.var(Y_test))
print("RMSE / Variance : ", np.sqrt(mean_squared_error(Y_test, Y_test_pred)) / np.var(Y_test))
print("RMSE / (max(Y) - min(Y)) : ", np.sqrt(mean_squared_error(Y_test, Y_test_pred)) / (np.max(Y_test) - np.min(Y_test)))

# Store results
results = results._append({'Model': 'Ridge', 'R2_train': r2_score(Y_train, Y_train_pred), 'R2_test': r2_score(Y_test, Y_test_pred), 'RMSE': np.sqrt(mean_squared_error(Y_test, Y_test_pred))}, ignore_index=True)
# Out:
# Training model with best alpha= 0.1 ...
# ...Done.
#
# Predictions on training set...
# ...Done.
# [134.43012134  31.82738298 167.78508443 ... 113.96062421 105.62359402
#  133.1188311 ]
#
# Predictions on test set...
# ...Done.
# R2 score on training set :  0.7210519224773009
# R2 score on test set :  0.6600567493550039
# MSE :  345.2728075941195
# RMSE :  18.58151790339313
# Variance :  1015.6777842743192
# RMSE / Variance :  0.018294697581348836
# RMSE / (max(Y) - min(Y)) :  0.05049325517226394

# %%
# Matrix of coefficients
print("Coefficients : ", model.coef_)
print("Intercept : ", model.intercept_)
print()
# Out:
# Coefficients :  [-13.54284694  14.32165959  -4.42387638  -6.38878117   4.00561492
#   20.076821    11.49084161   7.31655458 -14.14823127  14.68840251
#   -9.08304595 -20.85806309  -2.66270796   4.7016439   16.82782806
#    9.00919632  25.24283132  12.50763684  28.00432997  32.25657028
#  -19.62988877  -0.46677891  -3.11821987   1.01368328 -25.27280648
#   -2.14699995  -4.77518166   3.57245781  -6.74353744   3.44334158
#    3.11526449 -10.38199269  -8.66327066  -3.81899272  -8.3114795
#    4.43879396 -33.0753662    1.14806667  12.39984871   1.21150192
#    4.13378691   5.21488723   5.38985237  -3.95835569]
# Intercept :  117.49302374009399

# %%
# Cross validation
scores = cross_val_score(model, X_train, Y_train, cv=5)
print("Cross validation scores : ", scores)
print("Mean cross validation score : ", scores.mean())
print("Standard deviation of cross validation scores : ", scores.std())
# Out:
# Cross validation scores :  [0.69757202 0.6809462  0.69079193 0.74873177 0.73383234]
# Mean cross validation score :  0.7103748497970761
# Standard deviation of cross validation scores :  0.0262105156636485

# %%
# Plot predictions vs true values
plt.scatter(Y_test, Y_test_pred)
plt.xlabel('True values')
plt.ylabel('Predictions')
plt.title('Predictions vs true values')
plt.axis('equal')
plt.axis('square')
plt.plot(Y_test, Y_test, color='red')
plt.show()

# %%
#   Plot residuals distribution
sns.distplot(Y_test_pred - Y_test)
plt.title('Residuals distribution')
plt.show()
# Out:
# C:\Users\morab\AppData\Local\Temp\ipykernel_10600\1337168087.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Y_test_pred - Y_test)

# %%
# Plot feature importance for Ridge Regression

importances = np.abs(model.coef_) # Get the magnitude of the coefficients
indices = np.argsort(importances)[::-1] # Sort the feature indices by importance

plt.figure(figsize=(10, 10))
plt.title("Feature importances for Ridge Regression")

# Since Ridge regression coefficients can be negative (indicating inverse relationships),
# and we're interested in the magnitude of influence, we plot the absolute values.
plt.bar(range(X_train.shape[1]), importances[indices], color="b", align="center")

# If feature names are not directly available, you might use numerical indices
feature_names = np.array(X_train.columns if hasattr(X_train, "columns") else range(X_train.shape[1]))
plt.xticks(range(X_train.shape[1]), feature_names[indices], rotation=90)

plt.xlim([-1, X_train.shape[1]])
plt.xlabel('Features')
plt.ylabel('Absolute Coefficient Magnitude')
plt.show()

# %%
# Save model
pickle.dump(model, open('model_ridge.pkl','wb'))

# %% [markdown]
# #   Model Random Forest

# %%
'''
# Gridsearch for RandomForestRegressor
print("Gridsearch for RandomForestRegressor...")

regressor = RandomForestRegressor()
parameters = {'max_depth':[5, 10, 20], 'max_features':[10, 15, 20, 30, 40], 'min_samples_leaf':[2, 5], 'min_samples_split':[2, 5], 'n_estimators':[50, 100, 200, 300]}
grid = GridSearchCV(regressor, parameters, cv=5)
grid.fit(X_train, Y_train)
print("Best score : ", grid.best_score_)
print("Best parameters : ", grid.best_params_)
print("Best estimator : ", grid.best_estimator_)

# Train RandomForestRegressor with best parameters
model_rf = grid.best_estimator_
model_rf.fit(X_train, Y_train)
Y_train_pred = model_rf.predict(X_train)
Y_test_pred = model_rf.predict(X_test)
print("R2 score on training set : ", r2_score(Y_train, Y_train_pred))
print("R2 score on test set : ", r2_score(Y_test, Y_test_pred))
'''
# Out:
# '\n# Gridsearch for RandomForestRegressor\nprint("Gridsearch for RandomForestRegressor...")\n\nregressor = RandomForestRegressor()\nparameters = {\'max_depth\':[5, 10, 20], \'max_features\':[10, 15, 20, 30, 40], \'min_samples_leaf\':[2, 5], \'min_samples_split\':[2, 5], \'n_estimators\':[50, 100, 200, 300]}\ngrid = GridSearchCV(regressor, parameters, cv=5)\ngrid.fit(X_train, Y_train)\nprint("Best score : ", grid.best_score_)\nprint("Best parameters : ", grid.best_params_)\nprint("Best estimator : ", grid.best_estimator_)\n\n# Train RandomForestRegressor with best parameters\nmodel_rf = grid.best_estimator_\nmodel_rf.fit(X_train, Y_train)\nY_train_pred = model_rf.predict(X_train)\nY_test_pred = model_rf.predict(X_test)\nprint("R2 score on training set : ", r2_score(Y_train, Y_train_pred))\nprint("R2 score on test set : ", r2_score(Y_test, Y_test_pred))\n'

# %%
# Linear regression random forest
regressor = RandomForestRegressor(n_estimators=100, random_state=0, max_depth=20, max_features=15, min_samples_leaf=2, min_samples_split=2, n_jobs=-1, verbose=1, bootstrap=True)
regressor.fit(X_train, Y_train)
Y_train_pred = regressor.predict(X_train)
Y_test_pred = regressor.predict(X_test)
print("R2 score on training set : ", r2_score(Y_train, Y_train_pred))
print("R2 score on test set : ", r2_score(Y_test, Y_test_pred))

# Plot predictions vs true values
plt.scatter(Y_test, Y_test_pred)
plt.xlabel('True values')
plt.ylabel('Predictions')
plt.axis('equal')
plt.axis('square')
plt.plot(Y_test, Y_test, color='red')
plt.title('Predictions vs true values')
plt.show()

# Plot residuals distribution
sns.distplot(Y_test_pred - Y_test)
plt.title('Residuals distribution')
plt.show()

# Metrics of the model
print("MSE : ", mean_squared_error(Y_test, Y_test_pred))
print("RMSE : ", np.sqrt(mean_squared_error(Y_test, Y_test_pred)))
print("Variance : ", np.var(Y_test))
print("RMSE / Variance : ", np.sqrt(mean_squared_error(Y_test, Y_test_pred) / np.var(Y_test)))
print("RMSE / (max(Y) - min(Y)) : ", np.sqrt(mean_squared_error(Y_test, Y_test_pred) / (np.max(Y_test) - np.min(Y_test))))

# Store results
results = results._append({'Model': 'RandomForestRegressor', 'R2_train': r2_score(Y_train, Y_train_pred), 'R2_test': r2_score(Y_test, Y_test_pred), 'RMSE': np.sqrt(mean_squared_error(Y_test, Y_test_pred))}, ignore_index=True)

# Save model
pickle.dump(regressor, open('model_randomfr.pkl','wb'))
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 16 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    0.0s
# R2 score on training set :  0.8996632358991373
# R2 score on test set :  0.739834066580608
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    0.1s finished
# [Parallel(n_jobs=16)]: Using backend ThreadingBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done  18 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=16)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=16)]: Using backend ThreadingBackend with 16 concurrent workers.
# [Parallel(n_jobs=16)]: Done  18 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=16)]: Done 100 out of 100 | elapsed:    0.0s finished
# C:\Users\morab\AppData\Local\Temp\ipykernel_10600\1458906837.py:20: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# ...

# %%
# Plot feature importance for random forest
importances = regressor.feature_importances_
indices = np.argsort(importances)[::-1]
plt.figure(figsize=(10, 10))
plt.title("Feature importances")
plt.bar(range(X_train.shape[1]), importances[indices], color="r", align="center")
plt.xticks(range(X_train.shape[1]), indices)
plt.xlim([-1, X_train.shape[1]])
plt.show()

# %% [markdown]
# #   Model GradientBoostingRegressor

# %%
'''
# Gradient Boosting Regressor gridsearch with regularization
print("Gridsearch for GradientBoostingRegressor...")
regressor = GradientBoostingRegressor()
parameters = {'n_estimators':[50, 100, 200], 'max_depth':[3, 5, 10], 'min_samples_split':[2, 5], 'min_samples_leaf':[1, 2, 5], 'max_features':[10, 15, 20]}
grid = GridSearchCV(regressor, parameters, cv=5)
grid.fit(X_train, Y_train)
print("Best score : ", grid.best_score_)
print("Best parameters : ", grid.best_params_)
print("Best estimator : ", grid.best_estimator_)
print("...Done.")

# Train GradientBoostingRegressor with best parameters
best_parameters = grid.best_params_
regressor = GradientBoostingRegressor(n_estimators=best_parameters['n_estimators'], max_depth=best_parameters['max_depth'], min_samples_split=best_parameters['min_samples_split'], min_samples_leaf=best_parameters['min_samples_leaf'], max_features=best_parameters['max_features']) 
regressor.fit(X_train, Y_train)
Y_train_pred = regressor.predict(X_train)
Y_test_pred = regressor.predict(X_test)
print("R2 score on training set : ", r2_score(Y_train, Y_train_pred))
print("R2 score on test set : ", r2_score(Y_test, Y_test_pred))
'''
# Out:
# '\n# Gradient Boosting Regressor gridsearch with regularization\nprint("Gridsearch for GradientBoostingRegressor...")\nregressor = GradientBoostingRegressor()\nparameters = {\'n_estimators\':[50, 100, 200], \'max_depth\':[3, 5, 10], \'min_samples_split\':[2, 5], \'min_samples_leaf\':[1, 2, 5], \'max_features\':[10, 15, 20]}\ngrid = GridSearchCV(regressor, parameters, cv=5)\ngrid.fit(X_train, Y_train)\nprint("Best score : ", grid.best_score_)\nprint("Best parameters : ", grid.best_params_)\nprint("Best estimator : ", grid.best_estimator_)\nprint("...Done.")\n\n# Train GradientBoostingRegressor with best parameters\nbest_parameters = grid.best_params_\nregressor = GradientBoostingRegressor(n_estimators=best_parameters[\'n_estimators\'], max_depth=best_parameters[\'max_depth\'], min_samples_split=best_parameters[\'min_samples_split\'], min_samples_leaf=best_parameters[\'min_samples_leaf\'], max_features=best_parameters[\'max_features\']) \nregressor.fit(X_train, Y_train)\nY_train_pred =
# ...

# %%
# Gradient Boosting Regressor with best parameters
regressor = GradientBoostingRegressor(n_estimators=200, max_depth=5, min_samples_split=5, min_samples_leaf=2, max_features=15)
regressor.fit(X_train, Y_train)
Y_train_pred = regressor.predict(X_train)
Y_test_pred = regressor.predict(X_test)
print("R2 score on training set : ", r2_score(Y_train, Y_train_pred))
print("R2 score on test set : ", r2_score(Y_test, Y_test_pred))

# Plot predictions vs true values
plt.scatter(Y_test, Y_test_pred)
plt.xlabel('True values')
plt.ylabel('Predictions')
plt.title('Predictions vs true values')
plt.axis('equal')
plt.axis('square')
plt.plot(Y_test, Y_test, color='red')
plt.show()

# Plot residuals distribution
sns.distplot(Y_test_pred - Y_test)
plt.title('Residuals distribution')
plt.show()

# Metrics for model evaluation
print("MSE : ", mean_squared_error(Y_test, Y_test_pred))
print("RMSE : ", np.sqrt(mean_squared_error(Y_test, Y_test_pred)))
print("Variance : ", np.var(Y_test))
print("RMSE / Variance : ", np.sqrt(mean_squared_error(Y_test, Y_test_pred) / np.var(Y_test)))
print("RMSE / (max(Y) - min(Y)) : ", np.sqrt(mean_squared_error(Y_test, Y_test_pred) / (np.max(Y_test) - np.min(Y_test))))

# Store results
results = results._append({'Model': 'GradientBoostingRegressor', 'R2_train': r2_score(Y_train, Y_train_pred), 'R2_test': r2_score(Y_test, Y_test_pred), 'RMSE': np.sqrt(mean_squared_error(Y_test, Y_test_pred))}, ignore_index=True)

# Save model
pickle.dump(regressor, open('model_gradientboost.pkl','wb'))
# Out:
# R2 score on training set :  0.8859247210916866
# R2 score on test set :  0.7411322076007739
# C:\Users\morab\AppData\Local\Temp\ipykernel_10600\103725353.py:20: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(Y_test_pred - Y_test)
# MSE :  262.92626580403066
# RMSE :  16.215001258218596
# Variance :  1015.6777842743192
# RMSE / Variance :  0.5087905191719145
# RMSE / (max(Y) - min(Y)) :  0.8452653715730452

# %%
# Plot feature importance for GradientBoostingRegressor

importances = regressor.feature_importances_ # Get the magnitude of the coefficients
indices = np.argsort(importances)[::-1] # Sort the feature indices by importance
plt.figure(figsize=(10, 10))
plt.title("Feature importances")
plt.bar(range(X_train.shape[1]), importances[indices], color="r", align="center")
plt.xticks(range(X_train.shape[1]), indices)
plt.xlim([-1, X_train.shape[1]])
plt.show()

# %% [markdown]
# #   Results

# %%
# Show results
print('Here are the results of the different models:')
display(results)
# Out:
# Here are the results of the different models:
#                        Model  R2_train   R2_test       RMSE
# 0          Linear Regression  0.721055  0.659938  18.584753
# 1                      Lasso  0.704977  0.653362  18.763586
# 2                      Ridge  0.721052  0.660057  18.581518
# 3      RandomForestRegressor  0.899663  0.739834  16.255607
# 4  GradientBoostingRegressor  0.885925  0.741132  16.215001
